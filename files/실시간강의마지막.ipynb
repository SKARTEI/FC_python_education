# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot([1,2,3],[1,2,3])

plt.show()

# %%
plt.scatter([1,2,3],[1,2,3])

# %%
plt.bar([1,2,3],[1,2,3])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie([1,2,3])
# Out:
# ([<matplotlib.patches.Wedge at 0x15442874f40>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, ''),
#   Text(-0.5500000594609755, 0.9526279098330699, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %%
plt.figure(figsize=(20, 5)) # 가로길이, 세로길이 
plt.plot([1,2,3], [1,2,3], marker='o') # 마커 o로 표시하겠음
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
means = [20, 34, 30, 35, 27]
x = np.arange(len(labels)) # the label locations
rec = plt.bar(labels , means , 0.5) # 막대의 두께: 0.5,
plt.xticks(x, labels)
plt.title("bar plot", fontsize=12)
plt.show()

# %%
<!DOCTYPE html>
<html>
<head>
<title>HELLO HTML</title>
<meta charset='utf-8’>
</head>
<body> <h3>대충 제목이 들어갈 자리</h3>
<p>대충 내용이 들어갈 자리입니다.</p>
<p>대충 내용이 들어가는 중입니다. 간장 공장 공장장입니다.</p>
</body>
</html>
# Out:
#   File "<ipython-input-20-c7f15ae91100>", line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %%
<html>
<head>
<title>HELLO HTML</title>
<meta charset='utf-8'>
</head>
<body> <h3>대충 제목이 들어갈 자리</h3>
<p>대충 내용이 들어갈 자리입니다.</p>
<p>대충 내용이 들어가는 중입니다. 간장 공장 공장장입니다.</p>
</body>
</html>
# Out:
#   File "<ipython-input-21-c755faac4015>", line 1
#     <html>
#     ^
# SyntaxError: invalid syntax

# %%
import requests

# %%
response = requests.get("https://jsonplaceholder.typicode.com/users/1")
response.status_code
# Out:
# 200

# %%
response = requests.get("https://jsonplaceholder.typicode.com/users/100")
response.status_code
# Out:
# 404

# %%
url = "https://www.naver.com"
response = requests.get(url)
print("status code : ", response.status_code)

html = response.text
print(html)
# Out:
# status code :  200
#
# ...

# %%
paramDict = {"a":"bbb","b":123}
url = "http://www.naver.com"
response = requests.get(url, paramDict)
print("status code :", response.status_code)
# Out:
# status code : 200

# %%
datas = {"a":"bbb","b":123}
url = "http://www.naver.com"

response = requests.post(url, data=datas)
print("status code: ", response.status_code)
# Out:
# status code:  200

# %%
url = "https://www.naver.com"
response = requests.post(url, auth=("id","pass"))
print("status code : ", response.status_code)
# Out:
# status code :  200

# %%
import requests
url = "https://www.naver.com"

rs = requests.get(url)

rs_code = rs.status_code
if int(rs_code) ==200:
    print("Okay")
    rs_text = rs.text
    print(rs_text)
else :
    print(rs_code) 
    print("Fail")
# Out:
# Okay
#
# ...

# %%
import requests
url = "https://www.naver.com"

rs = request.post("https://www.naver.com")

rs_code = rs.status_code
if int(rs_code) ==200:
    print("Okay")
    rs_text = rs.text
    print(rs_text)
else :
    print(rs_code)
    print("Fail")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1c010423a3d8> in <module>
#       2 url = "https://www.naver.com"
#       3
# ----> 4 rs = request.post("https://www.naver.com")
#       5
#       6 rs_code = rs.status_code
#
# NameError: name 'request' is not defined

# %%
import json

# %%
item = {"id":1, "name": "book", "content": [{"title":"python for beginner","contents":"study python"}]}

jsonString = json.dumps(item)
print(item)
print(type(item))
print("\n")
print(jsonString)
print(type(jsonString))
# Out:
# {'id': 1, 'name': 'book', 'content': [{'title': 'python for beginner', 'contents': 'study python'}]}
# <class 'dict'>
#
#
# {"id": 1, "name": "book", "content": [{"title": "python for beginner", "contents": "study python"}]}
# <class 'str'>

# %%
import json
with open('/test.json','r') as f:
    json_data = json.load(f)

print(json.dumps(json_data))
#json 파일 읽기

with open('/result.json', 'w', encoding='utf-8') as make_file:
    json.dump(json_data, make_file, indent= "\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-54239f65ca9f> in <module>
#       1 import json
# ----> 2 with open('/test.json','r') as f:
#       3     json_data = json.load(f)
#       4
#       5 print(json.dumps(json_data))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/test.json'

# %%
import urllib.request

# %%
client_id = "pvzZehZqYe1mDhzStOKa" 
client_secret = "2Eq0F6k7YN"

# %%
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText +"&display=3&sort=count"

# %%
search_request = urllib.request.Request(url)
search_request.add_header("X-Naver-Client-Id",client_id)
search_request.add_header("X-Naver-Client-Secret",client_secret)

# %%
response = urllib.request.urlopen(search_request)
rescode = response.getcode()
print(rescode)
# Out:
# 200

# %%
if(rescode == 200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code" + rescode)
# Out:
# {
# "lastBuildDate": "Wed, 27 Jan 2021 14:57:27 +0900",
# "total": 1212,
# "start": 1,
# "display": 3,
# "items": [
# {
# "title": "혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15028688",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/286/15028688.jpg?type=m1&udate=20200915",
# "author": "윤인성",
# "price": "18000",
# "discount": "16200",
# "publisher": "한빛미디어",
# "pubdate": "20190610",
# "isbn": "1162241888 9791162241882",
# "description": "1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서(<b>파이썬</b> 최신 버전 반영)\n이 책은 독학으로 프로그래밍 언어를 처음 배우려는 입문자가, 혹은 <b>파이썬</b>을 배우려는 입문자가 ‘꼭 필요한 내용을 제대로’ 학습할 수 있도록 구성했다. ‘무엇을’, ‘어떻게’ 학습해야 할지조차 모르는 입문자의 막연한 마음을 살펴... "
#
# },
# {
# "title": "Do it! 점프 투 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15052904",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20200910",
# "author": "박응용",
# "price": "18800",
# "discount": "16920",
# ...
